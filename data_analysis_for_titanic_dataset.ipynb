# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 63.0+ KB

# %%
data_type = pd.DataFrame(titanic.dtypes)
data_type
# Out:
#                     0
# survived        int64
# pclass          int64
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# fare          float64
# embarked       object
# class        category
# who            object
# adult_male       bool
# deck         category
# embark_town    object
# alive          object
# alone            bool

# %%
data_type['missing_values'] = titanic.isnull().sum()
data_type
# Out:
#                     0  missing_values
# survived        int64               0
# pclass          int64               0
# sex            object               0
# age           float64             177
# sibsp           int64               0
# parch           int64               0
# fare          float64               0
# embarked       object               2
# class        category               0
# who            object               0
# adult_male       bool               0
# deck         category             688
# embark_town    object               2
# alive          object               0
# alone            bool               0

# %%
titanic[titanic["who"]=="man"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[titanic["sex"]=="female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(titanic[titanic["who"]=="man"])
# Out:
# 537

# %%
titanic[titanic["who"]=="woman"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(titanic[titanic["who"]=="woman"])
# Out:
# 271

# %%
titanic[(titanic["who"]=="woman") &(titanic["alive"]=="yes") ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[(titanic["who"]=="woman") &(titanic["alive"]=="no") ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 18          0       3  female  31.0      1      0  18.0000        S   Third
# 38          0       3  female  18.0      2      0  18.0000        S   Third
# 40          0       3  female  40.0      1      0   9.4750        S   Third
# 41          0       2  female  27.0      1      0  21.0000        S  Second
# 49          0       3  female  18.0      1      0  17.8000        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 854         0       2  female  44.0      1      0  26.0000        S  Second
# 863         0       3  female   NaN      8      2  69.5500        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[(titanic["who"]=="man") &(titanic["survived"]==1) ]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 828         1       3  male   NaN      0      0   7.7500        Q   Third
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.heatmap(titanic.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic[titanic["alone"]== "False"]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
#How many people were in Third class?
len(titanic[(titanic["class"]=="Third")])
# Out:
# 491

# %%
titanic[(titanic["class"]=="Third")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 884         0       3    male  25.0      0      0   7.0500        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# #How many people were in Third class and were alive after ?

len(titanic[(titanic["class"]=="Third") &  (titanic["alive"]=="yes")])
# Out:
# 119

# %%
titanic[(titanic["class"]=="Third") &  (titanic["alive"]=="yes")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 8           1       3  female  27.0      0      2  11.1333        S  Third
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 19          1       3  female   NaN      0      0   7.2250        C  Third
# 22          1       3  female  15.0      0      0   8.0292        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 838         1       3    male  32.0      0      0  56.4958        S  Third
# 855         1       3  female  18.0      0      1   9.3500        S  Third
# 858         1       3  female  24.0      0      3  19.2583        C  Third
# 869         1       3    male   4.0      1      1  11.1333        S  Third
# 875         1       3  female  15.0      0      0   7.2250        C  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# #How many people were in First class and were alive after ?

len(titanic[(titanic["class"]=="First") & (titanic["alive"]=="yes")])
# Out:
# 136

# %%
titanic[(titanic["class"]=="First") & (titanic["alive"]=="yes")]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
# 889         1       1    male  26.0      0      0   30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Average survived age
survived = titanic[titanic["alone"]==True]
survived['age'].mean()
# Out:
# 32.22029702970297

# %%
# How many people were alone?
len(titanic[titanic["alone"]==True])
# Out:
# 537

# %%
len(titanic[(titanic["class"]=="Third") & (titanic["sex"]=="female") & (titanic["alive"]=="yes")])
# Out:
# 72

# %%
len(titanic[(titanic["class"]=="Third") & (titanic["sex"]=="male") & (titanic["alive"]=="yes")])
# Out:
# 47

# %%
len(titanic[(titanic["class"]=="First") & (titanic["sex"]=="male") & (titanic["alive"]=="yes")])
# Out:
# 45

# %%
len(titanic[(titanic["class"]=="First") & (titanic["sex"]=="female") & (titanic["alive"]=="yes")])
# Out:
# 91

# %%
len(titanic[titanic["alone"]==False])
# Out:
# 354

# %%
print("Third Class:", len(titanic[titanic["class"]=="Third"]))
print("First Class:", len(titanic[titanic["class"]=="First"]))
# Out:
# Third Class: 491
# First Class: 216

# %%
len(titanic[titanic["age"]<5.0])
# Out:
# 40

# %%
len(titanic[(titanic["age"]<5.0) & (titanic["sex"]=="female")])
# Out:
# 17

# %%
len(titanic[(titanic["age"]<5.0) & (titanic["sex"]=="male")])
# Out:
# 23

# %%
len(titanic[(titanic["age"]>70.0) & (titanic["sex"]=="male")])
# Out:
# 5

# %%
len(titanic[(titanic["age"]>60.0) & (titanic["sex"]=="female")])
# Out:
# 3

# %%
titanic[(titanic["age"]>20.0) & (titanic["sex"]=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[(titanic["age"]>20.0) & (titanic["sex"]=="female")& (titanic["survived"]==1)& (titanic["alone"]==True)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 56          1       2  female  21.0      0      0  10.5000        S  Second
# 61          1       1  female  38.0      0      0  80.0000      NaN   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 797         1       3  female  31.0      0      0   8.6833        S   Third
# 829         1       1  female  62.0      0      0  80.0000      NaN   First
# 842         1       1  female  30.0      0      0  31.0000        C   First
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 865         1       2  female  42.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[(titanic["age"]>20.0) & (titanic["sex"]=="male")& (titanic["survived"]==1)& (titanic["alone"]==True)]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 21          1       2  male  34.0      0      0   13.0000        S  Second
# 23          1       1  male  28.0      0      0   35.5000        S   First
# 74          1       3  male  32.0      0      0   56.4958        S   Third
# 81          1       3  male  29.0      0      0    9.5000        S   Third
# 127         1       3  male  24.0      0      0    7.1417        S   Third
# 146         1       3  male  27.0      0      0    7.7958        S   Third
# 187         1       1  male  45.0      0      0   26.5500        S   First
# 207         1       3  male  26.0      0      0   18.7875        C   Third
# 209         1       1  male  40.0      0      0   31.0000        C   First
# 271         1       3  male  25.0      0      0    0.0000        S   Third
# 286         1       3  male  30.0      0      0    9.5000        S   Third
# ...

# %%
titanic["age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["age"].max()
# Out:
# 80.0

# %%
titanic["age"].min()
# Out:
# 0.42

# %%
titanic.age.plot(kind='hist',bins=30,color='orange')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.scatterplot(data=titanic, x='age', y='fare', hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>
